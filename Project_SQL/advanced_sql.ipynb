# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Первая-часть" data-toc-modified-id="Первая-часть-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Первая часть</a></span><ul class="toc-item"><li><span><a href="#Найдите-количество-вопросов,-которые-набрали-больше-300-очков-или-как-минимум-100-раз-были-добавлены-в-«Закладки»" data-toc-modified-id="Найдите-количество-вопросов,-которые-набрали-больше-300-очков-или-как-минимум-100-раз-были-добавлены-в-«Закладки»-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Найдите количество вопросов, которые набрали больше 300 очков или как минимум 100 раз были добавлены в «Закладки»</a></span></li><li><span><a href="#Сколько-в-среднем-в-день-задавали-вопросов-с-1-по-18-ноября-2008-включительно?" data-toc-modified-id="Сколько-в-среднем-в-день-задавали-вопросов-с-1-по-18-ноября-2008-включительно?-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Сколько в среднем в день задавали вопросов с 1 по 18 ноября 2008 включительно?</a></span></li><li><span><a href="#Сколько-пользователей-получили-значки-сразу-в-день-регистрации?" data-toc-modified-id="Сколько-пользователей-получили-значки-сразу-в-день-регистрации?-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Сколько пользователей получили значки сразу в день регистрации?</a></span></li><li><span><a href="#Сколько-уникальных-постов-пользователя-с-именем-Joel-Coehoorn-получили-хотя-бы-один-голос" data-toc-modified-id="Сколько-уникальных-постов-пользователя-с-именем-Joel-Coehoorn-получили-хотя-бы-один-голос-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Сколько уникальных постов пользователя с именем Joel Coehoorn получили хотя бы один голос</a></span></li><li><span><a href="#Выгрузите-все-поля-таблицы-vote_types." data-toc-modified-id="Выгрузите-все-поля-таблицы-vote_types.-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Выгрузите все поля таблицы vote_types.</a></span></li><li><span><a href="#Отберите-10-пользователей,-которые-поставили-больше-всего-голосов-типа-Close." data-toc-modified-id="Отберите-10-пользователей,-которые-поставили-больше-всего-голосов-типа-Close.-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Отберите 10 пользователей, которые поставили больше всего голосов типа Close.</a></span></li><li><span><a href="#Отберите-10-пользователей-по-количеству-значков,-полученных-в-период-с-15-ноября-по-15-декабря-2008-года-включительно" data-toc-modified-id="Отберите-10-пользователей-по-количеству-значков,-полученных-в-период-с-15-ноября-по-15-декабря-2008-года-включительно-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Отберите 10 пользователей по количеству значков, полученных в период с 15 ноября по 15 декабря 2008 года включительно</a></span></li><li><span><a href="#Сколько-в-среднем-очков-получает-пост-каждого-пользователя?" data-toc-modified-id="Сколько-в-среднем-очков-получает-пост-каждого-пользователя?-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Сколько в среднем очков получает пост каждого пользователя?</a></span></li><li><span><a href="#Отобразите-заголовки-постов,-которые-были-написаны-пользователями,-получившими-более-1000-значков." data-toc-modified-id="Отобразите-заголовки-постов,-которые-были-написаны-пользователями,-получившими-более-1000-значков.-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Отобразите заголовки постов, которые были написаны пользователями, получившими более 1000 значков.</a></span></li><li><span><a href="#Напишите-запрос,-который-выгрузит-данные-о-пользователях-из-США-(англ.-United-States).-Разделите-пользователей-на-три-группы-в-зависимости-от-количества-просмотров-их-профилей:" data-toc-modified-id="Напишите-запрос,-который-выгрузит-данные-о-пользователях-из-США-(англ.-United-States).-Разделите-пользователей-на-три-группы-в-зависимости-от-количества-просмотров-их-профилей:-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Напишите запрос, который выгрузит данные о пользователях из США (англ. United States). Разделите пользователей на три группы в зависимости от количества просмотров их профилей:</a></span></li><li><span><a href="#Дополните-предыдущий-запрос.-Отобразите-лидеров-каждой-группы-—-пользователей,-которые-набрали-максимальное-число-просмотров-в-своей-группе." data-toc-modified-id="Дополните-предыдущий-запрос.-Отобразите-лидеров-каждой-группы-—-пользователей,-которые-набрали-максимальное-число-просмотров-в-своей-группе.-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Дополните предыдущий запрос. Отобразите лидеров каждой группы — пользователей, которые набрали максимальное число просмотров в своей группе.</a></span></li><li><span><a href="#Посчитайте-ежедневный-прирост-новых-пользователей-в-ноябре-2008-года." data-toc-modified-id="Посчитайте-ежедневный-прирост-новых-пользователей-в-ноябре-2008-года.-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Посчитайте ежедневный прирост новых пользователей в ноябре 2008 года.</a></span></li><li><span><a href="#Для-каждого-пользователя,-который-написал-хотя-бы-один-пост,-найдите-интервал-между-регистрацией-и-временем-создания-первого-поста." data-toc-modified-id="Для-каждого-пользователя,-который-написал-хотя-бы-один-пост,-найдите-интервал-между-регистрацией-и-временем-создания-первого-поста.-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Для каждого пользователя, который написал хотя бы один пост, найдите интервал между регистрацией и временем создания первого поста.</a></span></li></ul></li><li><span><a href="#Вторая-часть" data-toc-modified-id="Вторая-часть-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Вторая часть</a></span><ul class="toc-item"><li><span><a href="#Выведите-общую-сумму-просмотров-постов-за-каждый-месяц-2008-года." data-toc-modified-id="Выведите-общую-сумму-просмотров-постов-за-каждый-месяц-2008-года.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выведите общую сумму просмотров постов за каждый месяц 2008 года.</a></span></li><li><span><a href="#Выведите-имена-самых-активных-пользователей,-которые-в-первый-месяц-после-регистрации-(включая-день-регистрации)-дали-больше-100-ответов." data-toc-modified-id="Выведите-имена-самых-активных-пользователей,-которые-в-первый-месяц-после-регистрации-(включая-день-регистрации)-дали-больше-100-ответов.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Выведите имена самых активных пользователей, которые в первый месяц после регистрации (включая день регистрации) дали больше 100 ответов.</a></span></li><li><span><a href="#Выведите-количество-постов-за-2008-год-по-месяцам." data-toc-modified-id="Выведите-количество-постов-за-2008-год-по-месяцам.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Выведите количество постов за 2008 год по месяцам.</a></span></li><li><span><a href="#Используя-данные-о-постах,-выведите-несколько-полей:" data-toc-modified-id="Используя-данные-о-постах,-выведите-несколько-полей:-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Используя данные о постах, выведите несколько полей:</a></span></li><li><span><a href="#Сколько-в-среднем-дней-в-период-с-1-по-7-декабря-2008-года-включительно-пользователи-взаимодействовали-с-платформой?" data-toc-modified-id="Сколько-в-среднем-дней-в-период-с-1-по-7-декабря-2008-года-включительно-пользователи-взаимодействовали-с-платформой?-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Сколько в среднем дней в период с 1 по 7 декабря 2008 года включительно пользователи взаимодействовали с платформой?</a></span></li><li><span><a href="#На-сколько-процентов-менялось-количество-постов-ежемесячно-с-1-сентября-по-31-декабря-2008-года?" data-toc-modified-id="На-сколько-процентов-менялось-количество-постов-ежемесячно-с-1-сентября-по-31-декабря-2008-года?-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>На сколько процентов менялось количество постов ежемесячно с 1 сентября по 31 декабря 2008 года?</a></span></li><li><span><a href="#Выгрузите-данные-активности-пользователя,-который-опубликовал-больше-всего-постов-за-всё-время." data-toc-modified-id="Выгрузите-данные-активности-пользователя,-который-опубликовал-больше-всего-постов-за-всё-время.-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Выгрузите данные активности пользователя, который опубликовал больше всего постов за всё время.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Проект по продвинутому SQL

# %% [markdown]
# ***Цель:*** решение задач по выгрузке данных
#
# **Исходные данные**
#
# - таблица с информацией о значках, которые присуждаются за разные достижения (идентификатор и название значка, идентификатор пользователя, дата присвоения)
# - таблица с данными о типе постов (индентификатор поста, тип поста (вопрос/ответ))
# - таблица с данными о постах (идентификатор, заголовок, даты создания и изменения, идентификатор пользователя-создателя, индентификатор типа поста, идентификатор связанного поста, количество просмотров и добавлений в избранное)
# - данные о пользователях (идентификатор и имя пользователя, дата регистрации, дата последнего входа, местоположение, репутация, число просмотров профиля)
# - данные о типах голосов (название и идентификатор типа голоса):
#     - UpMod — посты с вопросами или ответами, которые пользователи посчитали уместными и полезными;
#     - DownMod — посты, которые показались пользователям наименее полезными;
#     - Close — ставят опытные пользователи сервиса, если заданный вопрос нужно доработать или он вообще не подходит для платформы;
#     - Offensive — пользователь ответил на вопрос в грубой и оскорбительной манере, например, указав на неопытность автора поста.
#     - Spam — пост пользователя выглядит откровенной рекламой.
# - данные о голосах за посты (идентификаторы голоса, поста, пользователя и типа голоса, сумма вознаграждения для привлечения внимания к посту, дата назначения голоса)
#
# ![image.png](attachment:image.png)

# %%
# !pip install sqlalchemy 

# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
# устанавливаем параметры
db_config = {
    'user': '-censored-', # имя пользователя
    'pwd': '-censored-', # пароль
    'host': '-censored-',
    'port': censored, # порт подключения
    'db': '-censored-' # название базы данных
}

# %%
# устанавливаем параметры
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)

# %%
# !pip install psycopg2

# %%
# сохраняем коннектор
engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %%
# сохраняем коннектор
engine = create_engine(connection_string)

# %%
# функция для загрузки данных из sql базы
def select(sql):
    return pd.io.sql.read_sql(sql, con = engine)

# %%
# вывод первых строк таблицы с книгами
sql_b = '''
        SELECT *
        FROM stackoverflow.badges
        LIMIT 5
        '''
select(sql_b)
# Out:
#       id     name  user_id       creation_date
# 0  82947  Teacher      994 2008-09-15 08:55:04
# 1  82949  Teacher     3893 2008-09-15 08:55:04
# 2  82950  Teacher     4591 2008-09-15 08:55:04
# 3  82951  Teacher     5196 2008-09-15 08:55:04
# 4  82952  Teacher     2635 2008-09-15 08:55:04

# %% [markdown]
# ## Первая часть
# ### Найдите количество вопросов, которые набрали больше 300 очков или как минимум 100 раз были добавлены в «Закладки»

# %%
query = '''
        SELECT COUNT(*)
        FROM stackoverflow.posts AS p
        LEFT JOIN stackoverflow.post_types AS pt ON p.post_type_id = pt.id
        WHERE pt.type = 'Question' AND (p.score>300 OR p.favorites_count>=100);
        '''
select(query)
# Out:
#    count
# 0   1355

# %% [markdown]
# ### Сколько в среднем в день задавали вопросов с 1 по 18 ноября 2008 включительно?
# Результат округлите до целого числа

# %%
query = '''
        SELECT ROUND(AVG(num),0)
        FROM 
            (SELECT DISTINCT
                CAST(DATE_TRUNC('days', p.creation_date) AS date) AS dt,
                COUNT(p.id) OVER (PARTITION BY CAST(DATE_TRUNC('days', p.creation_date) AS date)) AS num
            FROM stackoverflow.posts AS p
            LEFT JOIN stackoverflow.post_types AS pt ON p.post_type_id = pt.id
            WHERE pt.type = 'Question' AND CAST(DATE_TRUNC('days', p.creation_date) AS date) BETWEEN '2008-11-01' AND '2008-11-18') grouped
        '''
select(query)
# Out:
#    round
# 0  383.0

# %% [markdown]
# ### Сколько пользователей получили значки сразу в день регистрации?
# Выведите количество уникальных пользователей

# %%
query = '''
        SELECT COUNT(DISTINCT u.id)
        FROM stackoverflow.users AS u
        JOIN stackoverflow.badges AS b ON u.id = b.user_id
        WHERE CAST(DATE_TRUNC('days', u.creation_date) AS date) = CAST(DATE_TRUNC('days', b.creation_date) AS date);
        '''
select(query)
# Out:
#    count
# 0   7047

# %% [markdown]
# ### Сколько уникальных постов пользователя с именем Joel Coehoorn получили хотя бы один голос

# %%
query = '''
        SELECT COUNT(DISTINCT p.id)
        FROM stackoverflow.posts AS p
        JOIN stackoverflow.users AS u ON p.user_id = u.id
        RIGHT JOIN stackoverflow.votes AS v ON p.id = v.post_id
        WHERE u.display_name = 'Joel Coehoorn'
        '''
select(query)
# Out:
#    count
# 0     12

# %% [markdown]
# ### Выгрузите все поля таблицы vote_types.
# Добавьте к таблице поле rank, в которое войдут номера записей в обратном порядке.
# Таблица должна быть отсортирована по полю id

# %%
query = '''
        SELECT *,
               ROW_NUMBER() OVER (ORDER BY id DESC) AS rank
        FROM stackoverflow.vote_types
        ORDER BY id
        '''
select(query)
# Out:
#     id                   name  rank
# 0    1   AcceptedByOriginator    15
# 1    2                  UpMod    14
# 2    3                DownMod    13
# 3    4              Offensive    12
# 4    5               Favorite    11
# 5    6                  Close    10
# 6    7                 Reopen     9
# 7    8            BountyStart     8
# 8    9            BountyClose     7
# 9   10               Deletion     6
# 10  11             Undeletion     5
# 11  12                   Spam     4
# 12  13        InformModerator     3
# 13  14        ModeratorReview     2
# 14  15  ApproveEditSuggestion     1

# %% [markdown]
# ### Отберите 10 пользователей, которые поставили больше всего голосов типа Close.
# Отобразите таблицу из двух полей: идентификатором пользователя и количеством голосов. Отсортируйте данные сначала по убыванию количества голосов, потом по убыванию значения идентификатора пользователя

# %%
query = '''
        SELECT v.user_id,
                COUNT(v.id) AS num
        FROM stackoverflow.votes AS v
        JOIN stackoverflow.vote_types AS vt ON v.vote_type_id = vt.id
        WHERE vt.name = 'Close'
        GROUP BY v.user_id
        ORDER BY 2 DESC, 1 DESC 
        LIMIT 10               
        '''
select(query)
# Out:
#    user_id  num
# 0    20646   36
# 1    14728   36
# 2    27163   29
# 3    41158   24
# 4    24820   23
# 5     9345   23
# 6     3241   23
# 7    44330   20
# 8    38426   19
# 9    19074   19

# %% [markdown]
# ### Отберите 10 пользователей по количеству значков, полученных в период с 15 ноября по 15 декабря 2008 года включительно
# Отобразите несколько полей:
# - идентификатор пользователя;
# - число значков;
# - место в рейтинге — чем больше значков, тем выше рейтинг.
#
# Пользователям, которые набрали одинаковое количество значков, присвойте одно и то же место в рейтинге.
# Отсортируйте записи по количеству значков по убыванию, а затем по возрастанию значения идентификатора пользователя.

# %%
query = '''
        SELECT id,
                num,
                DENSE_RANK() OVER (ORDER BY num DESC)
        FROM
            (SELECT  u.id AS id,
                    COUNT(b.id) AS num
            FROM stackoverflow.users AS u
            JOIN stackoverflow.badges AS b ON u.id = b.user_id
            WHERE CAST(DATE_TRUNC('days', b.creation_date) AS date) BETWEEN '2008-11-15' AND '2008-12-15'
            GROUP BY 1) grouped
        ORDER BY 2 DESC, 1
        LIMIT 10                   
        '''
select(query)
# Out:
#       id  num  dense_rank
# 0  22656  149           1
# 1  34509   45           2
# 2   1288   40           3
# 3   5190   31           4
# 4  13913   30           5
# 5    893   28           6
# 6  10661   28           6
# 7  33213   25           7
# 8  12950   23           8
# 9  25222   20           9

# %% [markdown]
# ### Сколько в среднем очков получает пост каждого пользователя?
# Сформируйте таблицу из следующих полей:
# - заголовок поста;
# - идентификатор пользователя;
# - число очков поста;
# - среднее число очков пользователя за пост, округлённое до целого числа.
#
# Не учитывайте посты без заголовка, а также те, что набрали ноль очков.

# %%
query = '''
        SELECT title,
               user_id,
               score,
               ROUND(AVG(score) OVER (PARTITION BY user_id))
        FROM stackoverflow.posts AS p
        WHERE title != '' AND score != 0
        '''
select(query)
# Out:
#                                                    title  user_id  score  \
# 0                Diagnosing Deadlocks in SQL Server 2005        1     82
# 1                How do I calculate someone's age in C#?        1   1743
# 2      Why doesn't IE7 copy <pre><code> blocks to the...        1     37
# 3                          Calculate relative time in C#        1   1348
# 4      Wrapping StopWatch timing with a delegate or l...        1     92
# ...                                                  ...      ...    ...
# 47349            Multi-lingual projects in Visual Studio  3742716      1
# 47350  Change datatype when importing Excel file into...  3930756      5
# 47351  How to host a Silverlight app in a Sharepoint ...  4020932      8
# 47352  Getting counts for a paged SQL search stored p...  5696608      2
# 47353  Reuse of SQL stored procedures across applicat...  5696608      2
#
#        round
# 0      573.0
# 1      573.0
# 2      573.0
# 3      573.0
# 4      573.0
# ...

# %% [markdown]
# ### Отобразите заголовки постов, которые были написаны пользователями, получившими более 1000 значков.
# Посты без заголовков не должны попасть в список

# %%
query = '''
        WITH grouped AS
            (SELECT b.user_id AS user_id,
                   COUNT(b.id) AS num
            FROM stackoverflow.badges AS b
            GROUP BY 1)
        SELECT p.title
        FROM stackoverflow.posts AS p
        JOIN grouped AS g ON p.user_id = g.user_id
        WHERE title != '' AND g.num >1000;
        '''
select(query)
# Out:
#                                                title
# 0  What's the hardest or most misunderstood aspec...
# 1  What's the strangest corner case you've seen i...
# 2               Project management to go with GitHub
# 3       What are the correct version numbers for C#?

# %% [markdown]
# ### Напишите запрос, который выгрузит данные о пользователях из США (англ. United States). Разделите пользователей на три группы в зависимости от количества просмотров их профилей:
# - пользователям с числом просмотров больше либо равным 350 присвойте группу 1;
# - пользователям с числом просмотров меньше 350, но больше либо равно 100 — группу 2;
# - пользователям с числом просмотров меньше 100 — группу 3.
#
# Отобразите в итоговой таблице идентификатор пользователя, количество просмотров профиля и группу. Пользователи с нулевым количеством просмотров не должны войти в итоговую таблицу.

# %%
query = '''
        SELECT id,
                views,
               CASE
                   WHEN views >=350 THEN 1
                   WHEN views >= 100 AND views < 350 THEN 2
                   WHEN views <100 THEN 3
               END
        FROM stackoverflow.users
        WHERE location LIKE '%%United States%%' AND views!=0     
        '''
select(query)
# Out:
#           id  views  case
# 0          3  24396     1
# 1         13  35414     1
# 2         23    757     1
# 3         25   3837     1
# 4         36    505     1
# ...      ...    ...   ...
# 2359  354142      6     3
# 2360  335806      4     3
# 2361  129753    105     2
# 2362  182061     52     3
# 2363  301168     80     3
#
# [2364 rows x 3 columns]

# %% [markdown]
# ### Дополните предыдущий запрос. Отобразите лидеров каждой группы — пользователей, которые набрали максимальное число просмотров в своей группе.
# Выведите поля с идентификатором пользователя, группой и количеством просмотров. Отсортируйте таблицу по убыванию просмотров, а затем по возрастанию значения идентификатора

# %%
query = '''
        WITH x AS 
            (SELECT id,
                    views,
                    CASE
                       WHEN views >=350 THEN 1
                       WHEN views >= 100 AND views < 350 THEN 2
                       WHEN views <100 THEN 3
                   END AS group
            FROM stackoverflow.users
            WHERE location LIKE '%%United States%%' AND views!=0),
        y AS 
            (SELECT x.id AS id,
                   x.group AS groupss,
                   x.views AS views,
                   MAX(x.views) OVER (PARTITION BY x.group) AS max_views
            FROM x)
    
        SELECT id,
               groupss,
               views
        FROM y
        WHERE views=max_views
        ORDER BY 3 DESC, 1
        '''
select(query)
# Out:
#        id  groupss  views
# 0   16587        1  62813
# 1    9094        2    349
# 2    9585        2    349
# 3   15079        2    349
# 4   33437        2    349
# 5    3469        3     99
# 6    4829        3     99
# 7   19006        3     99
# 8   22732        3     99
# 9  403434        3     99

# %% [markdown]
# ### Посчитайте ежедневный прирост новых пользователей в ноябре 2008 года.
# Сформируйте таблицу с полями:
# - номер дня;
# - число пользователей, зарегистрированных в этот день;
# - сумму пользователей с накоплением.

# %%
query = '''
        SELECT *,
                SUM(num) OVER(ORDER BY dt)
        FROM
            (SELECT EXTRACT(DAY FROM creation_date::date) AS dt,
                    COUNT(id) AS num
            FROM stackoverflow.users
            WHERE CAST(DATE_TRUNC('month', creation_date) AS date) = '2008-11-01'
            GROUP BY 1) a
        '''
select(query)
# Out:
#       dt  num     sum
# 0    1.0   34    34.0
# 1    2.0   48    82.0
# 2    3.0   75   157.0
# 3    4.0  192   349.0
# 4    5.0  122   471.0
# 5    6.0  132   603.0
# 6    7.0  104   707.0
# 7    8.0   42   749.0
# 8    9.0   45   794.0
# 9   10.0   93   887.0
# 10  11.0  113  1000.0
# 11  12.0  113  1113.0
# 12  13.0   96  1209.0
# 13  14.0   89  1298.0
# 14  15.0   42  1340.0
# 15  16.0   32  1372.0
# 16  17.0   84  1456.0
# 17  18.0   89  1545.0
# 18  19.0  107  1652.0
# 19  20.0   95  1747.0
# 20  21.0   81  1828.0
# 21  22.0   40  1868.0
# 22  23.0   50  1918.0
# 23  24.0   84  2002.0
# 24  25.0  104  2106.0
# 25  26.0   98  2204.0
# 26  27.0   71  2275.0
# 27  28.0   56  2331.0
# 28  29.0   44  2375.0
# 29  30.0   33  2408.0

# %% [markdown]
# ### Для каждого пользователя, который написал хотя бы один пост, найдите интервал между регистрацией и временем создания первого поста.
# Отобразите:
# - идентификатор пользователя;
# - разницу во времени между регистрацией и первым постом.

# %%
query = '''
        WITH pst AS 
            (SELECT DISTINCT
                    p.user_id,
                    FIRST_VALUE(p.creation_date) OVER(PARTITION BY p.user_id ORDER BY p.creation_date) AS dt_first_post
            FROM stackoverflow.posts AS p)

        SELECT u.id,
                pst.dt_first_post - u.creation_date
        FROM stackoverflow.users AS u
        JOIN pst ON u.id = pst.user_id
        '''
select(query)
# Out:
#             id         ?column?
# 0            1  0 days 09:18:29
# 1            2  0 days 14:37:03
# 2            3  3 days 16:17:09
# 3            4 15 days 05:44:22
# 4            5  1 days 14:57:51
# ...        ...              ...
# 18844  3644960  0 days 00:00:00
# 18845  3742716 66 days 21:15:48
# 18846  3930756  8 days 02:11:55
# 18847  4020932 47 days 18:30:34
# 18848  5696608  0 days 00:24:59
#
# [18849 rows x 2 columns]

# %% [markdown]
# ## Вторая часть
# ### Выведите общую сумму просмотров постов за каждый месяц 2008 года.
# Если данных за какой-либо месяц в базе нет, такой месяц можно пропустить. Результат отсортируйте по убыванию общего количества просмотров

# %%
query = '''
        SELECT  DISTINCT
                CAST(DATE_TRUNC('month', creation_date) AS date) AS dt,
                SUM(views_count) OVER (PARTITION BY CAST(DATE_TRUNC('month', creation_date) AS date)) AS numb
        FROM stackoverflow.posts
        WHERE EXTRACT(YEAR FROM creation_date::date) = 2008
        ORDER BY numb DESC;
        '''
select(query)
# Out:
#            dt       numb
# 0  2008-09-01  452928568
# 1  2008-10-01  365400138
# 2  2008-11-01  221759651
# 3  2008-12-01  197792841
# 4  2008-08-01  131367083
# 5  2008-07-01     669895

# %% [markdown]
# Вероятно, активность в осенние месяцы связана с началом учебного года. Данные за июль, вероятно, не полные.

# %% [markdown]
# ### Выведите имена самых активных пользователей, которые в первый месяц после регистрации (включая день регистрации) дали больше 100 ответов.
# Вопросы, которые задавали пользователи, не учитывайте. Для каждого имени пользователя выведите количество уникальных значений user_id. Отсортируйте результат по полю с именами в лексикографическом порядке.

# %%
query = '''
        SELECT  u.display_name AS full_name,
                COUNT(DISTINCT u.id) AS user_id
        FROM stackoverflow.posts AS p
        JOIN stackoverflow.users AS u ON p.user_id = u.id
        JOIN stackoverflow.post_types AS pt ON p.post_type_id = pt.id
        WHERE pt.type = 'Answer' AND p.creation_date::date <= u.creation_date::date + interval '1 month'
        GROUP BY u.display_name
        HAVING COUNT(p.id)>100
        ORDER BY 1
        '''
select(query)
# Out:
#            full_name  user_id
# 0   1800 INFORMATION        1
# 1      Adam Bellaire        1
# 2         Adam Davis        1
# 3          Adam Liss        1
# 4               Alan        8
# ..               ...      ...
# 74            lomaxx        1
# 75          mattlant        1
# 76         paxdiablo        1
# 77        tvanfosson        1
# 78              tzot        1
#
# [79 rows x 2 columns]

# %% [markdown]
# Одному имени соответствует несколько user_id, из чего следует, что анализ по имени проводить некорректно.

# %% [markdown]
# ### Выведите количество постов за 2008 год по месяцам.
# Отберите посты от пользователей, которые зарегистрировались в сентябре 2008 года и сделали хотя бы один пост в декабре того же года. Отсортируйте таблицу по значению месяца по убыванию.

# %%
query = '''
        WITH a AS
            (SELECT DISTINCT p.user_id
            FROM stackoverflow.posts AS p
            WHERE DATE_TRUNC('month', p.creation_date)::date = '2008-12-01')

        SELECT DATE_TRUNC('month', p.creation_date)::date AS dt,
                COUNT(p.id)
        FROM stackoverflow.posts AS p
        JOIN stackoverflow.users AS u ON p.user_id=u.id
        JOIN a ON u.id = a.user_id
        WHERE EXTRACT(YEAR FROM CAST(p.creation_date AS date)) = 2008
                AND DATE_TRUNC('month', u.creation_date)::date = '2008-09-01'
        GROUP BY 1
        ORDER BY 1 DESC
        '''
select(query)
# Out:
#            dt  count
# 0  2008-12-01  17641
# 1  2008-11-01  18294
# 2  2008-10-01  27171
# 3  2008-09-01  24870
# 4  2008-08-01     32

# %% [markdown]
# Пользователи, зарегистрированные в сентябре, делали посты в августе. Это стоит рассматривать как аномалию.

# %% [markdown]
# ### Используя данные о постах, выведите несколько полей:
# - идентификатор пользователя, который написал пост;
# - дата создания поста;
# - количество просмотров у текущего поста;
# - сумму просмотров постов автора с накоплением.
#
# Данные в таблице должны быть отсортированы по возрастанию идентификаторов пользователей, а данные об одном и том же - пользователе — по возрастанию даты создания поста.

# %%
query = '''
        SELECT user_id,
                creation_date AS dt,
                views_count,
                SUM(views_count) OVER(PARTITION BY user_id ORDER BY creation_date)
        FROM stackoverflow.posts AS p
        ORDER BY 1, 2
        '''
select(query)
# Out:
#         user_id                  dt  views_count     sum
# 0             1 2008-07-31 23:41:00       480476  480476
# 1             1 2008-07-31 23:55:38       136033  616509
# 2             1 2008-07-31 23:56:41            0  616509
# 3             1 2008-08-04 02:45:08            0  616509
# 4             1 2008-08-04 04:31:03            0  616509
# ...         ...                 ...          ...     ...
# 243791  5696608 2008-12-23 16:00:37            0    2804
# 243792  5696608 2008-12-23 17:35:09            0    2804
# 243793  5696608 2008-12-24 01:02:48            0    2804
# 243794  5696608 2008-12-30 14:34:45            0    2804
# 243795  5696608 2008-12-30 16:32:12            0    2804
#
# [243796 rows x 4 columns]

# %% [markdown]
# ### Сколько в среднем дней в период с 1 по 7 декабря 2008 года включительно пользователи взаимодействовали с платформой?
# Для каждого пользователя отберите дни, в которые он или она опубликовали хотя бы один пост. Нужно получить одно целое число — не забудьте округлить результат.

# %%
query = '''
        WITH a AS 
            (SELECT user_id,
                    COUNT(DISTINCT DATE_TRUNC('day', p.creation_date)::date) AS n
        FROM stackoverflow.posts AS p
        WHERE DATE_TRUNC('day', p.creation_date)::date BETWEEN '2008-12-01' AND '2008-12-07'
        GROUP BY 1)

        SELECT ROUND(AVG(n))
        FROM a
        '''
select(query)
# Out:
#    round
# 0    2.0

# %% [markdown]
# ### На сколько процентов менялось количество постов ежемесячно с 1 сентября по 31 декабря 2008 года?
# Отобразите таблицу со следующими полями:
# - номер месяца;
# - количество постов за месяц;
# - процент, который показывает, насколько изменилось количество постов в текущем месяце по сравнению с предыдущим.
#
# Если постов стало меньше, значение процента должно быть отрицательным, если больше — положительным. Округлите значение процента до двух знаков после запятой.
# Напомним, что при делении одного целого числа на другое в PostgreSQL в результате получится целое число, округлённое до ближайшего целого вниз. Чтобы этого избежать, переведите делимое в тип numeric.

# %%
query = '''
        SELECT months,
                cnt,
                ROUND(-100.0 + cnt::numeric*100.0/LAG(cnt) OVER(),2) AS perc
        FROM
            (SELECT EXTRACT(MONTH FROM creation_date) AS months,
                    COUNT(id) AS cnt
            FROM stackoverflow.posts
            WHERE DATE_TRUNC('month', creation_date)::date BETWEEN '2008-09-01' AND '2008-12-01'
            GROUP BY 1) a
        '''
select(query)
# Out:
#    months    cnt   perc
# 0     9.0  70371    NaN
# 1    10.0  63102 -10.33
# 2    11.0  46975 -25.56
# 3    12.0  44592  -5.07

# %% [markdown]
# ### Выгрузите данные активности пользователя, который опубликовал больше всего постов за всё время.
# Выведите данные за октябрь 2008 года в таком виде:
# - номер недели;
# - дата и время последнего поста, опубликованного на этой неделе.

# %%
query = '''
        WITH a AS
            (SELECT DISTINCT FIRST_VALUE(user_id) OVER() AS user_id
        FROM
            (SELECT user_id,
                    COUNT(id) AS cnt
            FROM stackoverflow.posts
            GROUP BY 1
            ORDER BY 2 DESC) A)

        SELECT  DISTINCT
                EXTRACT(WEEK FROM p.creation_date) AS weeks,
                MAX(p.creation_date) OVER(PARTITION BY EXTRACT(WEEK FROM p.creation_date))
        FROM stackoverflow.posts AS p
        JOIN a ON p.user_id = a.user_id
        WHERE  DATE_TRUNC('month', creation_date)::date = '2008-10-01' 
        '''
select(query)
# Out:
#    weeks                 max
# 0   40.0 2008-10-05 09:00:58
# 1   41.0 2008-10-12 21:22:23
# 2   42.0 2008-10-19 06:49:30
# 3   43.0 2008-10-26 21:44:36
# 4   44.0 2008-10-31 22:16:01
